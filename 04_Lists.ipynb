# %% [markdown]
# # List
#
# A list is a data type that allows you to store various types data in it
#
# Lists are used to store multiple items in a single variable.
#
# Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.

# %% [markdown]
# # Definition and accessing a list

# %% [markdown]
# To create a list all you have to do is to place the items inside a square bracket [] separated by comma ,.

# %%
mylist =['first','second','third','fourth']
secondlist=[3,7,4,2]

# %%
mylist
# Out:
# ['first', 'second', 'third', 'fourth']

# %%
secondlist
# Out:
# [3, 7, 4, 2]

# %% [markdown]
# # Use index of an item to access the item
# ## (index start from 0)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
mylist[0]
# Out:
# 'first'

# %%
# Update elements
#We can change the values of elements in a List
secondlist[3]=100

# %%
secondlist
# Out:
# [3, 7, 4, 100]

# %%
# Use ranges to slice a list[firstindex : lolastindex]. Last index will not include.
secondlist[1:3] # sublist in Python using slicing
# Out:
# [7, 4]

# %%
# Negative Index to access the list items from the end
secondlist[-1]
# Out:
# 100

# %% [markdown]
# #  List Methods

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Adding elements

# %%
#Add to the end of the  list
print(mylist)
mylist.append("fifth")
print(mylist)
# Out:
# ['first', 'second', 'third', 'fourth']
# ['first', 'second', 'third', 'fourth', 'fifth']

# %%
#Add to specific location in the list
mylist.insert(0,"new elemnt")

# %%
mylist
# Out:
# ['new elemnt', 'first', 'second', 'third', 'fourth', 'fifth']

# %% [markdown]
# # Deleting elements

# %% [markdown]
# Deleting elements using remove(), pop() and clear() methods
#
# remove(item): Removes specified item from list.
#
# pop(index): Removes the element from the given index.
#
# pop(): Removes the last element.
#
# clear(): Removes all the elements from the list.

# %%
#Delete an element from a list in  specific location
del mylist[0]

# %%
mylist
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth']

# %%
#deletes the last element in the list
mylist.pop()
mylist
# Out:
# ['first', 'second', 'third', 'fourth']

# %%
mylist.pop(2)
# Out:
# 'third'

# %%
mylist
# Out:
# ['first', 'second', 'fourth']

# %%
mylist.remove("second")
mylist
# Out:
# ['first', 'fourth']

# %% [markdown]
# # Sorting the list

# %%
mylist=[2,4,1,6,9,3,5]
sorted(mylist)
# Out:
# [1, 2, 3, 4, 5, 6, 9]

# %%
mylist
# Out:
# [2, 4, 1, 6, 9, 3, 5]

# %%
mylist.sort()

# %%
mylist
# Out:
# [1, 2, 3, 4, 5, 6, 9]

# %%
# The primary difference between the list sort() function and the sorted() 
# function is that the sort() function will modify the list it is called on. 
# The sorted() function will create a new list containing a sorted version
# of the list it is given

# %%
mylist.reverse()

# %%
mylist
# Out:
# [9, 6, 5, 4, 3, 2, 1]

# %%
#Find the length of a list
len(mylist)
# Out:
# 7

# %%
max(mylist)
# Out:
# 9

# %%
min(mylist)
# Out:
# 1

# %%
sum(mylist)
# Out:
# 30

# %%
avg=sum(mylist)/len(mylist)
avg
# Out:
# 4.285714285714286

# %%
# we can put several datatypes in the same list
l=["name",23,'g',45.6,True]
print(l)
# Out:
# ['name', 23, 'g', 45.6, True]

# %%
l1=['a','b','c']
l2=[1,2,3]
l3=l1+l2

# %%
l3
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
l3[3]
# Out:
# 1

# %%
l4=[l1,l2]

# %%
l4
# Out:
# [['a', 'b', 'c'], [1, 2, 3]]

# %% [markdown]
# # Keep Learning , Searching And Parcticing
# ### Good Luck
