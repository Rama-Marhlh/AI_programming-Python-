# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # If statement

# %% [markdown]
# If statements are control flow statements which helps us to run a particular code only when a certain condition is satisfied. For example, you want to print a message on the screen only when a condition is true then you can use if statement to accomplish this in programming

# %%
#if conditional_test:
# do something(block_of_code)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Simple if Statements

# %%
x=5
if x==5:
    print(x*2)
    print("inside if")
print("outside if")
# Out:
# 10
# inside if
# outside if

# %% [markdown]
# There are other control flow statements available in Python such as if..else, if..elif..else,
# nested if etc.

# %% [markdown]
# # if-else Statements

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y=2
if y<6:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
grade=89
if grade>90:
    print("very good")
elif grade<90:
    print("good")
# Out:
# good

# %% [markdown]
# # The if-elif-else Chain

# %%
age = 12
if age < 4:
    print("Your admission cost is $0.")
elif age < 18:
    print("Your admission cost is $25.")
else:
    print("Your admission cost is $40.")
# Out:
# Your admission cost is $25.

# %%
x=1
if x!=2:
    print("x does not equal 2")
# Out:
# x does not equal 2

# %%
if (x==1) or (y==3):
    print("yes")
y
# Out:
# yes
# 2

# %%
if (x==1) and (y==3):
    print("yes")
print("out")
# Out:
# out

# %%
a=5
b=8
mx=a if(a>b) else b
print(mx)
# Out:
# 8

# %% [markdown]
# # Range Function
# The range funciton is used to create numerical lists.

# %% [markdown]
# The range() is an in-built function in Python. It returns a sequence of numbers starting from zero and increment by 1 by default and stops before the given number.

# %% [markdown]
# Function range()
# In the above example, we have iterated over a list using for loop. However we can also use a range() function in for loop to iterate over numbers defined by range().
#
# range(n): generates a set of whole numbers starting from 0 to (n-1).
# For example:
# range(8) is equivalent to [0, 1, 2, 3, 4, 5, 6, 7]
#
# range(start, stop): generates a set of whole numbers starting from start to stop-1.
# For example:
# range(5, 9) is equivalent to [5, 6, 7, 8]
#
# range(start, stop, step_size): The default step_size is 1 which is why when we didn’t specify the step_size, the numbers generated are having difference of 1. However by specifying step_size we can generate numbers having the difference of step_size.
# For example:
# range(1, 10, 2) is equivalent to [1, 3, 5, 7, 9]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mylist=[1,2,3,4]
print(f"mylist is :{mylist}")

# we can use the range funciton to make the same list
# range function has two parameters (from, to) the to is execluded

newlist=list(range(1,5)) 
print(f"newlist is :{newlist}")

# range function can be used with 3 parameters (from, to, step)
oddlist=list(range(1,11,2)) 
print(f"oddlist is :{oddlist}")
# Out:
# mylist is :[1, 2, 3, 4]
# newlist is :[1, 2, 3, 4]
# oddlist is :[1, 3, 5, 7, 9]

# %% [markdown]
# # Loops
# For loop

# %% [markdown]
# A loop is a used for iterating over a set of statements repeatedly. In Python we have three types of loops for, while and do-while.

# %%
# for range:
#    do something

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
for num in range(0,11,2):
    print(num)
print("end")
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# end

# %%
s='this is string'
print(s[0])
print(len(s))
for i in range(len(s)):
    print(s[i])
# Out:
# t
# 14
# t
# h
# i
# s
#
# i
# s
#
# s
# t
# r
# i
# n
# g

# %%
for i in s:
    if i=='s':
        continue #if you find s dont print it and continue to the last string
    print(i)
# Out:
# t
# h
# i
#
# i
#
# t
# r
# i
# n
# g

# %%
for i in range(16):
    if i%2==0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# 15

# %% [markdown]
# # while loop

# %% [markdown]
# While loop is used to iterate over a block of code repeatedly until a given condition returns false.

# %% [markdown]
# ## the difference between the for loop and the while loop
# The main difference is that we use while loop when we are not certain of the number of times the loop requires execution, on the other hand when we exactly know how many times we need to run the loop, we use for loop.

# %%
#while condition:
    #body_of_while

# %%
x = 3
while x< 10:
    print(x)
    x=x+1
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# # input()
# get data from user

# %%
name = input("enter you name")
print(name)
type(name)
# Out:
# enter you name3
# 3
# str

# %%
n =int(input('input number'))
while n<=10:
    print(n)
    n+=1
print("done")
# Out:
# input number4
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# done

# %%
a=5
while a:
    print(a)
    a-=1
print("out")
print(a)
# Out:
# 5
# 4
# 3
# 2
# 1
# out
# 0
