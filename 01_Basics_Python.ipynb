# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # print()

# %% [markdown]
# The print() function prints the specified message to the screen, or other standard output device. The message can be a string, or any other object, the object will be converted into a string before written to the screen.

# %%
print('hello pyhtom world')
print('3*5 = ',3*5)
# Out:
# hello pyhtom world
# 3*5 =  15

# %% [markdown]
# ## •Variables and Simple  Data  Types
# No need to define a data type of a variable in Python!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Variable name – Identifiers
#
#
# Variable name is known as identifier. There are few rules that you have to follow while naming the variables in Python.
# 1. The name of the variable must always start with either a letter or an underscore (_). For example: _str, str, num, _num are all valid name for the variables.
# 2. The name of the variable cannot start with a number. For example: 9num is not a valid variable name.
# 3. The name of the variable cannot have special characters such as %, $, # etc, they can only have alphanumeric characters and underscore (A to Z, a to z, 0-9 or _ ).
# 4. Variable name is case sensitive in Python which means num and NUM are two different variables in python.

# %% [markdown]
# ## Data Types
# A data type defines the type of data, for example 123 is an integer data while “hello” is a String type of data. The data types in Python are divided in two categories:
# 1. Immutable data types – Values cannot be changed.
# 2. Mutable data types – Values can be changed
#
# Immutable data types in Python are:
# 1. Numbers
# 2. String
# 3. Tuple
#
# Mutable data types in Python are:
# 1. List
# 2. Dictionaries
# 3. Sets

# %% [markdown]
# # Variables

# %%
num = 3

# %%
type(num)
# Out:
# int

# %%
num=3.4

# %%
type(num)
# Out:
# float

# %%
com =2+3j

# %%
type(com)
# Out:
# complex

# %%
name="r"

# %%
type(name)
# Out:
# str

# %%
b=True

# %%
type(b)
# Out:
# bool

# %% [markdown]
# # converting the data

# %%
# Converting Floats to Integers
i=2.3
type(i)
# Out:
# float

# %%
i=int(i)

# %%
i
# Out:
# 2

# %%
#Converting Integers to Floats
f = 57
print(float(f))
# Out:
# 57.0

# %%
# Converting with Strings
str(12)
# Out:
# '12'

# %% [markdown]
# # Avoiding Name Errors When Using Variables

# %%
msg="hello pyhton "
print(msg)
# Out:
# hello pyhton

# %% [markdown]
# # Strings

# %%
print("This is a string.")
print('This is also a string.')
print('''
efoihohftglrtihlknd
RPEOJPER eltjlt
wihoih
erjpeot''')
# Out:
# This is a string.
# This is also a string.
#
# efoihohftglrtihlknd
# RPEOJPER eltjlt
# wihoih
# erjpeot

# %% [markdown]
# # Changing Case in a String with Methods

# %%
name="rana wael"

# %%
name.title()
# Out:
# 'Rana Wael'

# %%
name.upper()
name.lower()
# Out:
# 'rana wael'

# %% [markdown]
# # Using Variables in Strings

# %%
first_name = "leen"
last_name = "ahmad"
full_name = f"the first name  is {first_name} and the last name is {last_name}"
print(full_name)
# Out:
# the first name  is leen and the last name is ahmad

# %%
print(f"Hello, {full_name.title()}!")
# Out:
# Hello, The First Name  Is Leen And The Last Name Is Ahmad!

# %% [markdown]
# # Adding Whitespace to Strings with Tabs or Newlines

# %% [markdown]
# To add a tab to your text, use the character combination \t as shown

# %%
print("pyhton")
print("\tpyhton")
# Out:
# pyhton
# 	pyhton

# %% [markdown]
# To add a newline in a string, use the character combination \n:

# %%
print("Languages:\nPython\nC\nJavaScript")
# Out:
# Languages:
# Python
# C
# JavaScript

# %%
print("Languages:\n\tPython\n\tC\n\tJavaScript")
# Out:
# Languages:
# 	Python
# 	C
# 	JavaScript

# %% [markdown]
# # Stripping Whitespace
# this extra space is removed.

# %%
favorite_language = ' python ' 
print(favorite_language.rstrip())
print(favorite_language.lstrip())
print(favorite_language.strip())
# Out:
#  python
# python
# python

# %% [markdown]
# # Avoiding Syntax Errors with Strings

# %%
msg = "One of Python's strengths is its diverse community."
msg
# Out:
# "One of Python's strengths is its diverse community."

# %% [markdown]
# # Numbers ( Arithmetic operators)

# %% [markdown]
# # Integers
# You can add (+), subtract (-), multiply (*), and divide (/) integers in Python.

# %%
2+3
# Out:
# 5

# %%
2-3
# Out:
# -1

# %%
2*3
# Out:
# 6

# %%
3/2
# Out:
# 1.5

# %%
3//2
# Out:
# 1

# %%
3**2
# Out:
# 9

# %%
3%2
# Out:
# 1

# %% [markdown]
# #  Comparison operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
5 > 8
# Out:
# False

# %% [markdown]
# Identity operators (is, not is)
# Membership operators (in, not in)

# %% [markdown]
# # Logical operators (and, or, not)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# x or y , x and y , not x  
True and False
# Out:
# False

# %% [markdown]
# # Multiple Assignment

# %%
x,y,z=10,20,30
x,z
# Out:
# (10, 30)

# %% [markdown]
# # Constants
# Python doesn’t have built-in constant types, but Python programmers use all capital letters to indicate a variable should be treated as a
# constant and never be changed:

# %%
MAX_CONNECTIONS = 5000

# %% [markdown]
# # Comments

# %%
# say hello pyhton
print("hello python")
# Out:
# hello python

# %%
'''
this is long 
comment in 
python '''
# Out:
# '\nthis is long \ncomment in \npython '

# %% [markdown]
# Task
# Using the below three variables and comparison and logical operators, write the correct code to
# store the value (True) in a variable named bool_exp.

# %%
first_num = 10
second_num = 50
third_num = 14

# %%
first_num < second_num or second_num > third_num
# Out:
# True

# %% [markdown]
# # Keep Learning , Searching And Parcticing

# %% [markdown]
# ### Good Luck
